# %%
from threading import Thread
import keyboard
import time

def yolo(id, root, source):
    # !python {root}detect.py --weight {root}runs/train/insam_yolov5s_results/weights/best.pt --source {source} --save-txt --exist-ok --hide-conf --hide-labels
    return

def master(id, root):
    with open(root+"runs/detect/exp/result.txt", "r") as f:
        com = f.readlines()[0]
    while True:
        if keyboard.is_pressed(" "):
            with open(root+"runs/detect/exp/result.txt", "r") as f:
                try :
                    txt = f.readlines()[0]
                except IndexError : 
                    pass
                else :
                    if txt != com:
                        com = txt
                        GA, conveyer, DA, feeder, angle, x_coordinate, y_coordinate = txt.split(' ')
                        print('-------------SYNARIO-------------')
                        print(f'인삼 검출 갯수 : {GA}')
                        print(f'컨베이어 작동') if conveyer == '1' else print('컨베이어 멈춤')
                        print(f'정상 검출 갯수 : {DA}')
                        print('피더 작동') if feeder == '1' else print('피더 멈춤')
                        print(f'그리퍼 각도 : {angle}')
                        print(f'좌표 : {x_coordinate}, {y_coordinate}')
                        print('-'*33)
                        print(f'소켓OUT : {conveyer}, {feeder}, {angle}, {x_coordinate}, {y_coordinate}')
                        print('-'*33)
                        print(' ')
                        print(' ')
            time.sleep(1)
    return

if __name__ == "__main__":
    root = 'C:/Users/AI/firecat_e6/yolov5/'
    yolo = Thread(target=yolo, args=(1, root, 0))
    master = Thread(target=master, args=(2, root))
    yolo.start()
    master.start()
# Out:
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 1
# 컨베이어 멈춤
# 정상 검출 갯수 : 0
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 0
# 컨베이어 작동
# 정상 검출 갯수 : 0
# 피더 멈춤
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 1, 0, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 1
# 컨베이어 멈춤
# 정상 검출 갯수 : 0
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 0
# 컨베이어 작동
# 정상 검출 갯수 : 0
# 피더 멈춤
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 1, 0, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 2
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 483, 218
# ---------------------------------
# 소켓OUT : 0, 0, 315, 483, 218
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 324, 224
# ---------------------------------
# 소켓OUT : 0, 0, 90, 324, 224
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 483, 218
# ---------------------------------
# 소켓OUT : 0, 0, 315, 483, 218
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 324, 224
# ---------------------------------
# 소켓OUT : 0, 0, 90, 324, 224
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 410, 377
# ---------------------------------
# 소켓OUT : 0, 0, 315, 410, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 325, 110
# ---------------------------------
# 소켓OUT : 0, 0, 90, 325, 110
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 410, 377
# ---------------------------------
# 소켓OUT : 0, 0, 315, 410, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 578, 323
# ---------------------------------
# 소켓OUT : 0, 0, 315, 578, 323
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 492, 225
# ---------------------------------
# 소켓OUT : 0, 0, 315, 492, 225
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 410, 377
# ---------------------------------
# 소켓OUT : 0, 0, 315, 410, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 135
# 좌표 : 540, 153
# ---------------------------------
# 소켓OUT : 0, 0, 135, 540, 153
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 361
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 361
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 324, 224
# ---------------------------------
# 소켓OUT : 0, 0, 90, 324, 224
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 115, 8962
# ---------------------------------
# 소켓OUT : 0, 0, 90, 115, 8962
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 180
# 좌표 : 79, 113
# ---------------------------------
# 소켓OUT : 0, 0, 180, 79, 113
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 261, 262
# ---------------------------------
# 소켓OUT : 0, 0, 270, 261, 262
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 261, 263
# ---------------------------------
# 소켓OUT : 0, 0, 270, 261, 263
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 136, 101
# ---------------------------------
# 소켓OUT : 0, 0, 90, 136, 101
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 45
# 좌표 : 266, 180
# ---------------------------------
# 소켓OUT : 0, 0, 45, 266, 180
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 143, 134
# ---------------------------------
# 소켓OUT : 0, 0, 90, 143, 134
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 135
# 좌표 : 124, 137
# ---------------------------------
# 소켓OUT : 0, 0, 135, 124, 137
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 180
# 좌표 : 108, 152
# ---------------------------------
# 소켓OUT : 0, 0, 180, 108, 152
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 122, 164
# ---------------------------------
# 소켓OUT : 0, 0, 270, 122, 164
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 118, 166
# ---------------------------------
# 소켓OUT : 0, 0, 270, 118, 166
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 323, 196
# ---------------------------------
# 소켓OUT : 0, 0, 90, 323, 196
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 118, 166
# ---------------------------------
# 소켓OUT : 0, 0, 270, 118, 166
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 374, 180
# ---------------------------------
# 소켓OUT : 0, 0, 90, 374, 180
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 45
# 좌표 : 266, 180
# ---------------------------------
# 소켓OUT : 0, 0, 45, 266, 180
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 118, 175
# ---------------------------------
# 소켓OUT : 0, 0, 270, 118, 175
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 118, 174
# ---------------------------------
# 소켓OUT : 0, 0, 270, 118, 174
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 118, 175
# ---------------------------------
# 소켓OUT : 0, 0, 270, 118, 175
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 118, 175
# ---------------------------------
# 소켓OUT : 0, 0, 270, 118, 175
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 117, 175
# ---------------------------------
# 소켓OUT : 0, 0, 270, 117, 175
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 118, 175
# ---------------------------------
# 소켓OUT : 0, 0, 270, 118, 175
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 45
# 좌표 : 266, 180
# ---------------------------------
# 소켓OUT : 0, 0, 45, 266, 180
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 94, 138
# ---------------------------------
# 소켓OUT : 0, 0, 90, 94, 138
# ---------------------------------
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 138, 125
# ---------------------------------
# 소켓OUT : 0, 0, 90, 138, 125
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 45
# 좌표 : 147, 135
# ---------------------------------
# 소켓OUT : 0, 0, 45, 147, 135
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 130, 124
# ---------------------------------
# 소켓OUT : 0, 0, 90, 130, 124
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 135
# 좌표 : 117, 128
# ---------------------------------
# 소켓OUT : 0, 0, 135, 117, 128
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 45
# 좌표 : 266, 180
# ---------------------------------
# 소켓OUT : 0, 0, 45, 266, 180
# ---------------------------------
# detect: weights=['C:/Users/AI/firecat_e6/yolov5/runs/train/insam_yolov5s_results/weights/best.pt'], source=0, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=True, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5  v6.2-219-ga83d2a5 Python-3.9.12 torch-1.12.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
