# %%
from threading import Thread
import keyboard
import time
import os

def yolo(id, root, source):
    # !python {root}detect.py --weight {root}best.pt --source {source} --save-txt --exist-ok --hide-conf --hide-labels
    return

def master(id, root):
    with open(root+"runs/detect/exp/result.txt", "r") as f:
        com = f.readlines()[0]
    while True:
        if keyboard.is_pressed(" "):
            with open(root+"runs/detect/exp/result.txt", "r") as f:
                try :
                    txt = f.readlines()[0]
                except IndexError : 
                    pass
                else :
                    if txt != com:
                        com = txt
                        GA, conveyer, DA, feeder, angle, x_coordinate, y_coordinate = txt.split(' ')
                        print('-------------SYNARIO-------------')
                        print(f'인삼 검출 갯수 : {GA}')
                        print(f'컨베이어 작동') if conveyer == '1' else print('컨베이어 멈춤')
                        print(f'정상 검출 갯수 : {DA}')
                        print('피더 작동') if feeder == '1' else print('피더 멈춤')
                        print(f'그리퍼 각도 : {angle}')
                        print(f'좌표 : {x_coordinate}, {y_coordinate}')
                        print('-'*33)
                        print(f'소켓OUT : {conveyer}, {feeder}, {angle}, {x_coordinate}, {y_coordinate}')
                        print('-'*33)
                        print(' ')
                        print(' ')
            time.sleep(1)
    return

if __name__ == "__main__":
    root = os.getcwd()+'/'
    yolo = Thread(target=yolo, args=(1, root, 0))
    master = Thread(target=master, args=(2, root))
    yolo.start()
    master.start()
# Out:
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 0
# 좌표 : 299, 302
# ---------------------------------
# 소켓OUT : 0, 0, 0, 299, 302
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 257, 277
# ---------------------------------
# 소켓OUT : 0, 0, 270, 257, 277
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 257, 277
# ---------------------------------
# 소켓OUT : 0, 0, 270, 257, 277
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 495, 374
# ---------------------------------
# 소켓OUT : 0, 0, 270, 495, 374
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 187, 198
# ---------------------------------
# 소켓OUT : 0, 0, 270, 187, 198
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 187, 198
# ---------------------------------
# 소켓OUT : 0, 0, 270, 187, 198
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 495, 373
# ---------------------------------
# 소켓OUT : 0, 0, 270, 495, 373
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 495, 374
# ---------------------------------
# 소켓OUT : 0, 0, 270, 495, 374
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 203, 182
# ---------------------------------
# 소켓OUT : 0, 0, 270, 203, 182
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 203, 182
# ---------------------------------
# 소켓OUT : 0, 0, 270, 203, 182
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 180
# 좌표 : 163, 143
# ---------------------------------
# 소켓OUT : 0, 0, 180, 163, 143
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 198, 180
# ---------------------------------
# 소켓OUT : 0, 0, 270, 198, 180
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 0
# 좌표 : 230, 140
# ---------------------------------
# 소켓OUT : 0, 0, 0, 230, 140
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 195, 96
# ---------------------------------
# 소켓OUT : 0, 0, 90, 195, 96
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 205, 116
# ---------------------------------
# 소켓OUT : 0, 0, 90, 205, 116
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 45
# 좌표 : 72, 4
# ---------------------------------
# 소켓OUT : 0, 0, 45, 72, 4
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 3
# 컨베이어 작동
# 정상 검출 갯수 : 0
# 피더 멈춤
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 1, 0, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 238, 145
# ---------------------------------
# 소켓OUT : 0, 0, 90, 238, 145
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 150, 116
# ---------------------------------
# 소켓OUT : 0, 0, 90, 150, 116
# ---------------------------------
