# %% [markdown]
# # 12월 6일 발표 Code

# %%
from threading import Thread
import time

def yolo(id, root, source):
    # !python {root}detect126.py --weight {root}runs/train/insam_yolov5s_results/weights/best.pt --source {source} --save-txt --exist-ok --hide-conf --hide-labels
    return

def master(root):
    with open(root+"runs/detect/exp/result.txt", "r") as f:
        com = f.readlines()[0]
    while True:
        with open(root+"runs/detect/exp/result.txt", "r") as f:
            try :
                txt = f.readlines()[0]
            except IndexError : 
                pass
            else :
                if txt != com:
                    com = txt
                    GA, conveyer, DA, feeder, angle, x_coordinate, y_coordinate = txt.split(' ')
                    print('-------------SYNARIO-------------')
                    print(f'인삼 검출 갯수 : {GA}')
                    print(f'컨베이어 작동') if conveyer == '1' else print('컨베이어 멈춤')
                    print(f'정상 검출 갯수 : {DA}')
                    print('피더 작동') if feeder == '1' else print('피더 멈춤')
                    print(f'그리퍼 각도 : {angle}')
                    print(f'좌표 : {x_coordinate}, {y_coordinate}')
                    print('-'*33)
                    print(f'소켓OUT : {conveyer}, {feeder}, {angle}, {x_coordinate}, {y_coordinate}')
                    print('-'*33)
                    print(' ')
                    print(' ')
        time.sleep(1)
    return

if __name__ == '__main__' :
    print('main thread start!')
    root = 'C:/Users/AI/firecat_e6/yolov5/'
    # !python {root}detect126.py --weight {root}runs/train/insam_yolov5s_results/weights/best.pt --source 0 --save-txt --exist-ok --hide-conf --hide-labels
    master = Thread(target=master, args=(root), daemon = True)
    print('main thread end!')
# Out:
# main thread start!

# %% [markdown]
# # 베타

# %%
from threading import Thread
import time

def yolo(id, root, source):
    # !python {root}detect126.py --weight {root}runs/train/insam_yolov5s_results/weights/best.pt --source {source} --save-txt --exist-ok --hide-conf --hide-labels
    return

def master(id, root):
    with open(root+"runs/detect/exp/result.txt", "r") as f:
        com = f.readlines()[0]
    while True:
        with open(root+"runs/detect/exp/result.txt", "r") as f:
            try :
                txt = f.readlines()[0]
            except IndexError : 
                pass
            else :
                if txt != com:
                    com = txt
                    GA, conveyer, DA, feeder, angle, x_coordinate, y_coordinate = txt.split(' ')
                    print('-------------SYNARIO-------------')
                    print(f'인삼 검출 갯수 : {GA}')
                    print(f'컨베이어 작동') if conveyer == '1' else print('컨베이어 멈춤')
                    print(f'정상 검출 갯수 : {DA}')
                    print('피더 작동') if feeder == '1' else print('피더 멈춤')
                    print(f'그리퍼 각도 : {angle}')
                    print(f'좌표 : {x_coordinate}, {y_coordinate}')
                    print('-'*33)
                    print(f'소켓OUT : {conveyer}, {feeder}, {angle}, {x_coordinate}, {y_coordinate}')
                    print('-'*33)
                    print(' ')
                    print(' ')
        time.sleep(1)
    return

if __name__ == "__main__":
    root = 'C:/Users/AI/firecat_e6/yolov5/'
    yolo = Thread(target=yolo, args=(1, root, 0))
    master = Thread(target=master, args=(2, root))
    yolo.start()
    master.start()
# Out:
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 1
# 컨베이어 작동
# 정상 검출 갯수 : 0
# 피더 멈춤
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 1, 0, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 1
# 컨베이어 작동
# 정상 검출 갯수 : 0
# 피더 멈춤
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 1, 0, None, None, None
# ---------------------------------
# detect126: weights=['C:/Users/AI/firecat_e6/yolov5/runs/train/insam_yolov5s_results/weights/best.pt'], source=0, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=True, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5  v6.2-219-ga83d2a5 Python-3.9.12 torch-1.12.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# [ WARN:0@44.067] global D:\a\opencv-python\opencv-python\opencv\modules\videoio\src\cap_msmf.cpp (464) `anonymous-namespace'::SourceReaderCB::OnReadSample videoio(MSMF): OnReadSample() is called with error status: -1072875772
# [ WARN:0@44.069] global D:\a\opencv-python\opencv-python\opencv\modules\videoio\src\cap_msmf.cpp (476) `anonymous-namespace'::SourceReaderCB::OnReadSample videoio(MSMF): async ReadSample() call is failed with error status: -1072875772
# [ WARN:1@44.070] global D:\a\opencv-python\opencv-python\opencv\modules\videoio\src\cap_msmf.cpp (1752) CvCapture_MSMF::grabFrame videoio(MSMF): can't grab frame. Error: -1072875772
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
# [ WARN:2@44.070] global D:\a\opencv-python\opencv-python\opencv\modules\videoio\src\cap_msmf.cpp (1752) CvCapture_MSMF::grabFrame videoio(MSMF): can't grab frame. Error: -1072875772
# WARNING  Video stream unresponsive, please check your IP camera connection.
#
# Traceback (most recent call last):
#   File "C:\Users\AI\firecat_e6\yolov5\detect126.py", line 233, in <module>
#     main(opt)
#   File "C:\Users\AI\firecat_e6\yolov5\detect126.py", line 229, in main
#     run(**vars(opt))
#   File "C:\Users\AI\Anaconda3\lib\site-packages\torch\autograd\grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "C:\Users\AI\firecat_e6\yolov5\detect126.py", line 81, in run
#     dataset = LoadStreams(source, img_size=imgsz, stride=stride, auto=pt, vid_stride=vid_stride)
#   File "C:\Users\AI\firecat_e6\yolov5\utils\dataloaders.py", line 377, in __init__
#     s = np.stack([letterbox(x, img_size, stride=stride, auto=auto)[0].shape for x in self.imgs])
#   File "C:\Users\AI\firecat_e6\yolov5\utils\dataloaders.py", line 377, in <listcomp>
#     s = np.stack([letterbox(x, img_size, stride=stride, auto=auto)[0].shape for x in self.imgs])
#   File "C:\Users\AI\firecat_e6\yolov5\utils\augmentations.py", line 118, in letterbox
#     r = min(new_shape[0] / shape[0], new_shape[1] / shape[1])
# IndexError: tuple index out of range
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 2
# 컨베이어 작동
# 정상 검출 갯수 : 0
# 피더 멈춤
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 1, 0, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 2
# 컨베이어 작동
# 정상 검출 갯수 : 0
# 피더 멈춤
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 1, 0, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 3
# 컨베이어 작동
# 정상 검출 갯수 : 0
# 피더 멈춤
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 1, 0, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 3
# 컨베이어 작동
# 정상 검출 갯수 : 0
# 피더 멈춤
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 1, 0, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 1
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 1
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 0
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 0
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 1
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 1
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 2
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 2
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 2
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 2
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 1
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 1
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 232
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 232
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 232
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 232
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 2
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 4
# 컨베이어 멈춤
# 정상 검출 갯수 : 2
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 233
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 233
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 233
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 233
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 232
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 232
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 232
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 232
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 5
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 249, 379
# ---------------------------------
# 소켓OUT : 0, 0, 90, 249, 379
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 249, 379
# ---------------------------------
# 소켓OUT : 0, 0, 90, 249, 379
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 232
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 232
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 232
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 232
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 232
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 232
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 270
# 좌표 : 130, 232
# ---------------------------------
# 소켓OUT : 0, 0, 270, 130, 232
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 72, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 72, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 72, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 72, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 52, 295
# ---------------------------------
# 소켓OUT : 0, 0, 315, 52, 295
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 52, 295
# ---------------------------------
# 소켓OUT : 0, 0, 315, 52, 295
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 42, 311
# ---------------------------------
# 소켓OUT : 0, 0, 315, 42, 311
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 9
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 42, 311
# ---------------------------------
# 소켓OUT : 0, 0, 315, 42, 311
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 377
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 377
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 239, 362
# ---------------------------------
# 소켓OUT : 0, 0, 90, 239, 362
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 164, 420
# ---------------------------------
# 소켓OUT : 0, 0, 315, 164, 420
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 164, 420
# ---------------------------------
# 소켓OUT : 0, 0, 315, 164, 420
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 6
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 90
# 좌표 : 351, 376
# ---------------------------------
# 소켓OUT : 0, 0, 90, 351, 376
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 6
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 343, 297
# ---------------------------------
# 소켓OUT : 0, 0, 315, 343, 297
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 5
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 275
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 275
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 118, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 118, 276
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 119, 276
# ---------------------------------
# 소켓OUT : 0, 0, 315, 119, 276
# ---------------------------------
#
#
# ...
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 52
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 52
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 52
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 52
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 269
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 269
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 269
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 269
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 269
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 269
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 269
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 269
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 269
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 269
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 269
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 269
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 52
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 52
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 52
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 52
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 269
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 269
# ---------------------------------
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 380, 269
# ---------------------------------
# 소켓OUT : 0, 0, 315, 380, 269
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 105, 372
# ---------------------------------
# 소켓OUT : 0, 0, 315, 105, 372
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 8
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 105, 372
# ---------------------------------
# 소켓OUT : 0, 0, 315, 105, 372
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 2
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 2
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 52
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 52
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 52
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 52
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 267
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 267
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 267
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 267
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 379, 268
# ---------------------------------
# 소켓OUT : 0, 0, 315, 379, 268
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 269, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 269, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 269, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 269, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 0
# 좌표 : 240, 227
# ---------------------------------
# 소켓OUT : 0, 0, 0, 240, 227
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 0
# 좌표 : 240, 227
# ---------------------------------
# 소켓OUT : 0, 0, 0, 240, 227
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 0
# 좌표 : 240, 227
# ---------------------------------
# 소켓OUT : 0, 0, 0, 240, 227
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 0
# 좌표 : 240, 227
# ---------------------------------
# 소켓OUT : 0, 0, 0, 240, 227
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 52
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 52
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 52
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 52
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 267, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 267, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 267, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 267, 53
# ---------------------------------
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 0
# 좌표 : 240, 227
# ---------------------------------
# 소켓OUT : 0, 0, 0, 240, 227
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 0
# 좌표 : 240, 227
# ---------------------------------
# 소켓OUT : 0, 0, 0, 240, 227
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 267
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 267
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 267
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 267
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 382, 266
# ---------------------------------
# 소켓OUT : 0, 0, 315, 382, 266
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 3
# 피더 작동
# 그리퍼 각도 : None
# 좌표 : None, None
# ---------------------------------
# 소켓OUT : 0, 1, None, None, None
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------
#
#
# -------------SYNARIO-------------
# 인삼 검출 갯수 : 7
# 컨베이어 멈춤
# 정상 검출 갯수 : 4
# 피더 멈춤
# 그리퍼 각도 : 315
# 좌표 : 268, 53
# ---------------------------------
# 소켓OUT : 0, 0, 315, 268, 53
# ---------------------------------

# %% [markdown]
# # master

# %%
# 쓰레드 간 변수 주고 받는 모듈 공부 필요!

# %%
from threading import Thread
import time

def yolo(id, root, source):
    # !python {root}detect7.py --weight {root}runs/train/insam_yolov5s_results/weights/best.pt --source {source} --save-txt --exist-ok --hide-conf --hide-labels
    return

def master(id, root):
    com = 'initialization'
    while True:
        with open(root+"runs/detect/exp/result.txt", "r") as f:
            txt = f.readlines()
            if txt[0] != com:
#                 print(txt[0])
                com = txt[0]
                conv, feed, ang, x, y = txt[0].split(' ')
                if conv == 1:
                    print('컨베이어 작동')
                elif feed ==1 :
                    print('피더 작동')
                else:
                    pack = [cnt, [ang, x, y]]
                    ### 슬레이브로 pack 보내는 코드 입력자리 ###
                    print(f'번호:{cnt}, 각도:{ang}, X축:{x}, Y축:{y}')
        time.sleep(1)
    return

def slave(id):
    num, ang2, x2, y2=pack[0], pack[1][0], pack[1][1], pack[1][2]
    print('로봇 작업 내용')
    print(f'번호:{num}, 각도:{ang2}, X축:{x2}, Y축:{y2}')
    

if __name__ == "__main__":
    root = 'C:/Users/AI/Auto_Farming/yolov5/'
    yolo = Thread(target=yolo, args=(1, root, 0))
    master = Thread(target=master, args=(2, root))
#     slave = Thread(target=slave, arges=(3))
    yolo.start()
    master.start()
#     slave.start()

# %%
# 서버
import sys
import os
from pathlib import Path
with open(os.getcwd()+"/test.txt", "w") as f:
    f.write('0 0 90 250 350')
with open(os.getcwd()+"/test.txt", "r") as f:
    txt = str(*f.readlines())
conv, feed, ang, x, y = txt.split(' ')
cnt=0

# while True: 원래 while문인데 for문으로 대체해서 보여줌
for _ in range(801): # for문 안에 range 바꾸면 몇번째인지 바뀌겠지 
    if conv == 1:
        print('컨베이어 작동')
    elif feed ==1 :
        print('피더 작동')
    else:
        cnt += 1
        testlist = [cnt, [ang, x, y]] 
        if cnt == 800:
            cnt = 0

# %% [markdown]
# # 스레드로 실시간 좌표 확인

# %%
from threading import Thread
import time

def yolo(id, root, source):
    # !python {root}detect7.py --weight {root}runs/train/insam_yolov5s_results/weights/best.pt --source {source} --save-txt --exist-ok --hide-conf --hide-labels
    return

def synario(id, root):
    conc = 'initialization'
    while True:
        with open(root+"runs/detect/exp/result.txt", "r") as f:
            txt = f.readlines()
            if txt[0] != conc:
                print(txt[0])
                conc = txt[0]     
        time.sleep(1)
    return

if __name__ == "__main__":
    root = 'C:/Users/AI/Auto_Farming/yolov5/'
    th1 = Thread(target=yolo, args=(1, root, 0))
    th2 = Thread(target=synario, args=(2, root))
    th1.start()
    th2.start()

# %% [markdown]
# # detect.py test

# %%
root = 'C:/Users/AI/Auto_Farming/yolov5/'
detect = 'C:/Users/AI/Auto_Farming/yolov5/detect7py'
weight = 'C:/Users/AI/Auto_Farming/yolov5/runs/train/insam_yolov5s_results/weights/best.pt'
# !python {detect} --weight {weight} --source 0 --save-txt --exist-ok --hide-conf --hide-labels

# for i, j in enumerate(rs):
#     if i > 5:
#         print(j)

# %% [markdown]
# # image test

# %%
import os
import glob
import cv2
import math
import numpy as np
import matplotlib.pyplot as plt

frame_img_path = 'C:/Users/AI/Auto_Farming/yolov5/image/capture.png'
exp_path = "C:/Users/AI/Auto_Farming/yolov5/runs/detect/exp/"
path = 'C:/Users/AI/Auto_Farming/yolov5/'
weight = 'C:/Users/AI/Auto_Farming/yolov5/runs/train/insam_yolov5s_results/weights/best.pt'
source = 'C:/Users\AI/Auto_Farming/image/capture.png' 
coordinate_path = "C:/Users/AI/Auto_Farming/yolov5/runs/detect/exp/labels/"

# %%
# !python {path}detect3.py --weight {weight} --source {source} --save-txt --exist-ok --hide-conf --hide-labels

# %%
import os
import sys
import glob
from pathlib import Path
import math
import numpy as np

# FILE = Path(__file__).resolve()
# ROOT = FILE.parents[0]/'runs/detect/exp/'

gc, hc, ga, da = [], [], [], []
min_gl, a = float('inf'), 0

with open(coordinate_path+"capture.txt", "r") as f:
    txt = f.readlines()  

[gc.append(i) if i[0] == '0' else hc.append(i) for i in txt]

gn, hn, p = len(gc), len(hc), 0

for i in range(gn):
    g = gc[i][2:-1].split(' ')
    gltx, glty, grbx, grby = int(g[0]), int(g[1]), int(g[2]), int(g[3])
    lt, rt, lb, rb = [gltx, glty], [grbx, glty], [gltx, grby], [grbx, grby]
    globals()["g{}".format(i)] = [lt, rt, lb, rb]

    for j in range(hn):
        h = hc[j][2:-1].split(' ')
        hltx, hlty, hrbx, hrby = int(h[0]), int(h[1]), int(h[2]), int(h[3])
        globals()["h{}".format(j)] = [int((hltx+hrbx)/2), int((hlty+hrby)/2)]
        if (globals()[f"g{i}"][3][0] > globals()[f"h{j}"][0] > globals()[f"g{i}"][0][0])\
        and (globals()[f"g{i}"][3][1] > globals()[f"h{j}"][1] > globals()[f"g{i}"][0][1]):
            globals()["g{}".format(i)].append(globals()["h{}".format(j)])

    ga.append(globals()["g{}".format(i)])

for i in ga:
    if len(i) == 5:
        da.append(i)
        
# da=(1,2,3,4) # 개체수 없는 시나리오


if len(da) <= 5:
    p = 1
else: 
    for v in da:
        if min_gl > v[0][0]:
                min_gl = v[0][0]   
    for i,value in enumerate(da):
        if min_gl == value[0][0]:
            globals()["g{}".format(i)] = np.array(globals()["g{}".format(i)])
            best = globals()["g{}".format(i)]
            alt = abs(globals()["g{}".format(i)][0]-globals()["g{}".format(i)][-1])
            art = abs(globals()["g{}".format(i)][1]-globals()["g{}".format(i)][-1])
            alb = abs(globals()["g{}".format(i)][2]-globals()["g{}".format(i)][-1])
            arb = abs(globals()["g{}".format(i)][3]-globals()["g{}".format(i)][-1])
            altu, artu = int(math.sqrt((alt[0]**2)+(alt[1]**2))), int(math.sqrt((art[0]**2)+(art[1]**2)))
            albu, arbu = int(math.sqrt((alb[0]**2)+(alb[1]**2))), int(math.sqrt((arb[0]**2)+(arb[1]**2)))
            bgc = {'LT':altu, 'RT':artu, 'LB':albu, 'RB':arbu}
            bgc_sorted=sorted(bgc.items(), key=lambda x:x[1])
            if bgc_sorted[1][1] - bgc_sorted[0][1] < 20:
                if bgc_sorted[0][0] == 'RT' and bgc_sorted[1][0] == 'RB':
                    a=0
                elif bgc_sorted[1][0] == 'RT' and bgc_sorted[0][0] == 'RB':
                    a=0
                elif bgc_sorted[0][0] == 'LT'and bgc_sorted[1][0] == 'RT': 
                    a=90
                elif bgc_sorted[1][0] == 'LT'and bgc_sorted[0][0] == 'RT':
                    a=90
                elif bgc_sorted[0][0] == 'LT' and bgc_sorted[1][0] == 'LB':
                    a=180
                elif bgc_sorted[1][0] == 'LT' and bgc_sorted[0][0] == 'LB':
                    a=180
                elif bgc_sorted[0][0] == 'LB' and bgc_sorted[1][0] == 'RB': 
                    a=270
                elif bgc_sorted[1][0] == 'LB' and bgc_sorted[0][0] == 'RB':
                    a=270
            else:
                if bgc_sorted[0][0] == 'RT':
                    a=45
                elif bgc_sorted[0][0] == 'LT':
                    a=135
                elif bgc_sorted[0][0] == 'LB': 
                    a=225
                elif bgc_sorted[0][0] == 'RB':
                    a=315

print(f'정상 검출 갯수 : {len(da)}')
print('피더 작동') if p==1 else print('피더 작동 안함')
print(f'그리퍼 각도 : {a}')
print(f'좌표 : {best[-1][0]}, {best[-1][1]}')

# %%
best = g1
frame_img = cv2.imread(frame_img_path, cv2.IMREAD_COLOR)
frame_img = cv2.cvtColor(frame_img, cv2.COLOR_BGR2RGB)
frame_img = cv2.rectangle(frame_img, (best[0][0], best[0][1]), (best[3][0], best[3][1]),(0,255,0), 3)
frame_img = cv2.circle(frame_img, (best[-1][0],best[-1][1]),5,(255,0,0), -1)
plt.xticks([]); plt.yticks([])
plt.imshow(frame_img)
